# %%
import numpy
import pandas
import matplotlib.pyplot as pl

# %%
temp1 = numpy.genfromtxt("wasp47_usp_ttvs.txt",skip_header=10)
temp2 = numpy.delete(temp1, numpy.s_[0,2], axis=1)

# %%
# help(numpy.genfromtxt)

# %%
# goal: read the file, but use the pandas module, not numpy.genfromtxt()
# pandas.read_csv("wasp47_usp_ttvs.txt", skiprows = 9)

# %%
matplotlib.pyplot.plot(temp2)
